# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('1.bmp',0)

# %%
# import the necessary packages
import cv2
import numpy as np

# binarize the image
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

# define the kernel
kernel = np.ones((2, 2), np.uint8)

# invert the image
invert = cv2.bitwise_not(binr)

# erode the image
erosion = cv2.erode(invert, kernel,
					iterations=1)

# print the output
plt.imshow(erosion, cmap='gray')

# %%
kernel = np.ones((5, 5), np.uint8)

# %%
i = 0
while i<10:
    img_erosion = cv2.erode(img, kernel, iterations=1)
    img_dilation = cv2.dilate(img, kernel, iterations=1)
    i = i + 1

# %%
image=np.concatenate((img_erosion, img_dilation),axis=1)
cv2.imshow("ED Images",image)

# %%
cv2.destroyAllWindows()

# %%
img= cv2.imread('1.bmp')
img1=cv2.imread('1.bmp')
images=np.concatenate((img,img1),axis=1)
cv2.imshow("Images",images)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray_img1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow("gray", gray_img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# import the necessary packages
import cv2
import numpy as np
import matplotlib.pyplot as plt

# binarize the image
binr = cv2.threshold(img_dilation, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

# define the kernel
kernel = np.ones((2, 2), np.uint8)

# invert the image
invert = cv2.bitwise_not(binr)

# erode the image
erosion = cv2.erode(invert, kernel,
					iterations=1)

# print the output
plt.imshow(invert, cmap='gray')

# %%
plt.imshow(erosion, cmap='gray')
